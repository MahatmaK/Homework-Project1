# %%
# Dependencies
import requests
import json
import pandas as pd

# %%
AB = pd.read_csv('Resources/Chicago_listings.csv')
chicago_airbnb_df
# Out:
#             id                                               name    host_id  \
# 0         2384  Hyde Park - Walk to UChicago, 10 min to McCormick       2613
# 1         4505  394 Great Reviews. 127 y/o House. 40 yds to tr...       5775
# 2         7126                Tiny Studio Apartment 94 Walk Score      17928
# 3         9811                      Barbara's Hideaway - Old Town      33004
# 4        10945                              The Biddle House (#1)      33004
# ...        ...                                                ...        ...
# 6367  48199082  PVT ROOM|50% mthly OFF|15min walk to Kedzie BR...  211029191
# 6368  48199156             Stunning and spacious apt on Southport  378245394
# 6369  48199227  BR with PRIVATE OFFICE in Old Irving Pk / Avon...   31378386
# 6370  48201067                                          Cosy loft   75724040
# 6371  48202487          Beautiful convertible in downtown Chicago  388904253
#
# ...
